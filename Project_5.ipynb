# %% [markdown]
# ### Data Cleaning & Preparation

# %%
import pandas as pd

# Load and clean the data
df = pd.read_csv("C:/Users/ACER/Downloads/order_dataset.csv")
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df.drop_duplicates(inplace=True)

# Add return flag
df['Is Return'] = df['Final Quantity'] < 0

# %%
df
# Out:
#       Item Name   Category       Version                 Item Code  \
# 0           QID  Product H   32 / B / 30  27-0CD-F44-7E1-0-2F608D7
# 1           OTH  Product P  32 / B / FtO  37-9D1-AC6-D48-E-F2D4507
# 2           WHX  Product P  32 / B / FtO  85-2EB-163-D62-5-FC50316
# 3           RJF  Product P  33 / B / FtO  3D-687-99C-14F-4-661E2E7
# 4           TSH  Product D  34 / B / FtO  F9-9FA-787-104-B-DCEE379
# ...         ...        ...           ...                       ...
# 70047       RJF  Product P  36 / B / FtO  7C-D23-B98-39F-E-93ABC5C
# 70048       KNB  Product P  33 / A / FtO  10-D34-C89-3B7-8-77333AA
# 70049       XEB  Product D  34 / A / FtO  EA-048-158-A25-3-11DAA3E
# 70050       AYN  Product P  36 / B / FtO  89-517-B97-D81-B-F23CCC1
# 70051       NWB  Product H   36 / B / 32  08-E8A-524-409-1-7A032D2
#
#           Item ID   Buyer ID  Transaction ID       Date  Final Quantity  \
# 0      46567054.0  3301861.0    5.363560e+13 2019-04-14               1
# 1      16345004.0  1205940.0    4.759180e+13 2019-02-14              -1
# 2      26246865.0  3342830.0    9.211720e+13 2018-11-28              -1
# 3      42015157.0  7251983.0    5.987730e+13 2019-03-03               1
# 4      40522014.0  9940388.0    3.658240e+13 2018-11-26               1
# ...           ...        ...             ...        ...             ...
# 70047  56109013.0  3421398.0    1.498000e+13 2018-11-20               1
# 70048  35445869.0  1913362.0    1.506840e+13 2019-04-03               1
# 70049  27215940.0  9781863.0    6.776480e+13 2018-12-26               1
# 70050  89883040.0  6808059.0    2.156440e+13 2019-01-12               1
# 70051  11926413.0  3582530.0    6.202560e+13 2018-11-17               1
#
#        Total Revenue  Price Reductions  Refunds  Final Revenue  Sales Tax  \
# 0              74.17              0.00     0.00          74.17      14.83
# 1               0.00              0.00   -79.17         -79.17     -15.83
# 2               0.00              0.00   -74.17         -74.17     -14.83
# 3              79.17              0.00     0.00          79.17      15.83
# 4              74.17              0.00     0.00          74.17      14.83
# ...              ...               ...      ...            ...        ...
# 70047          79.16              0.00     0.00          79.16      15.84
# 70048          79.16             -7.91     0.00          71.25      14.25
# 70049          51.67              0.00     0.00          51.67      10.33
# 70050          55.00              0.00     0.00          55.00      11.00
# 70051          74.16              0.00     0.00          74.16      14.84
#
#        Overall Revenue  Refunded Item Count  Purchased Item Count  Is Return
# 0                 89.0                    0                     1      False
# 1                -95.0                   -1                     0       True
# 2                -89.0                   -1                     0       True
# 3                 95.0                    0                     1      False
# 4                 89.0                    0                     1      False
# ...                ...                  ...                   ...        ...
# 70047             95.0                    0                     1      False
# 70048             85.5                    0                     1      False
# 70049             62.0                    0                     1      False
# 70050             66.0                    0                     1      False
# 70051             89.0                    0                     1      False
#
# [70051 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# Item Name               0
# Category                0
# Version                 0
# Item Code               0
# Item ID                 0
# Buyer ID                0
# Transaction ID          0
# Date                    0
# Final Quantity          0
# Total Revenue           0
# Price Reductions        0
# Refunds                 0
# Final Revenue           0
# Sales Tax               0
# Overall Revenue         0
# Refunded Item Count     0
# Purchased Item Count    0
# Is Return               0
# dtype: int64

# %%
df.describe()
# Out:
#             Item ID      Buyer ID  Transaction ID  Final Quantity  \
# count  7.005100e+04  7.005100e+04    7.005100e+04    70051.000000
# mean   2.442353e+11  6.013177e+11    5.506035e+13        0.701175
# std    4.255107e+12  6.223245e+12    2.587637e+13        0.739501
# min    1.001447e+07  1.000661e+06    1.000660e+13       -3.000000
# 25%    2.692223e+07  3.295585e+06    3.270320e+13        1.000000
# 50%    4.494514e+07  5.566107e+06    5.522210e+13        1.000000
# 75%    7.743106e+07  7.815352e+06    7.736870e+13        1.000000
# max    8.422210e+13  9.977410e+13    9.999550e+13        6.000000
#
#        Total Revenue  Price Reductions       Refunds  Final Revenue  \
# count   70051.000000      70051.000000  70051.000000   70051.000000
# mean       61.776054         -4.949677    -10.246197      46.580180
# std        31.800848          7.769795     25.154827      51.803041
# min         0.000000       -200.000000   -237.500000    -237.500000
# 25%        51.670000         -8.340000      0.000000      47.080000
# 50%        74.170000          0.000000      0.000000      63.330000
# 75%        79.170000          0.000000      0.000000      74.170000
# max       445.000000          0.000000      0.000000     445.000000
#
#           Sales Tax  Overall Revenue  Refunded Item Count  \
# count  70051.000000     70051.000000         70051.000000
# mean       9.123600        55.703778            -0.156101
# std       10.305305        61.920976             0.369193
# min      -47.500000      -285.000000            -3.000000
# 25%        8.370000        56.225000             0.000000
# 50%       12.660000        76.000000             0.000000
# 75%       14.840000        89.000000             0.000000
# max       63.340000       445.000000             0.000000
#
#        Purchased Item Count
# count          70051.000000
# mean               0.857275
# std                0.380822
# min                0.000000
# 25%                1.000000
# 50%                1.000000
# 75%                1.000000
# max                6.000000

# %%
df.head()
# Out:
#   Item Name   Category       Version                 Item Code     Item ID  \
# 0       QID  Product H   32 / B / 30  27-0CD-F44-7E1-0-2F608D7  46567054.0
# 1       OTH  Product P  32 / B / FtO  37-9D1-AC6-D48-E-F2D4507  16345004.0
# 2       WHX  Product P  32 / B / FtO  85-2EB-163-D62-5-FC50316  26246865.0
# 3       RJF  Product P  33 / B / FtO  3D-687-99C-14F-4-661E2E7  42015157.0
# 4       TSH  Product D  34 / B / FtO  F9-9FA-787-104-B-DCEE379  40522014.0
#
#     Buyer ID  Transaction ID       Date  Final Quantity  Total Revenue  \
# 0  3301861.0    5.363560e+13 2019-04-14               1          74.17
# 1  1205940.0    4.759180e+13 2019-02-14              -1           0.00
# 2  3342830.0    9.211720e+13 2018-11-28              -1           0.00
# 3  7251983.0    5.987730e+13 2019-03-03               1          79.17
# 4  9940388.0    3.658240e+13 2018-11-26               1          74.17
#
#    Price Reductions  Refunds  Final Revenue  Sales Tax  Overall Revenue  \
# 0               0.0     0.00          74.17      14.83             89.0
# 1               0.0   -79.17         -79.17     -15.83            -95.0
# 2               0.0   -74.17         -74.17     -14.83            -89.0
# 3               0.0     0.00          79.17      15.83             95.0
# 4               0.0     0.00          74.17      14.83             89.0
#
#    Refunded Item Count  Purchased Item Count  Is Return
# 0                    0                     1      False
# 1                   -1                     0       True
# 2                   -1                     0       True
# 3                    0                     1      False
# 4                    0                     1      False

# %%
df.shape
# Out:
# (70051, 18)

# %% [markdown]
# ### Overall Return Rate

# %%
return_rate = df['Is Return'].mean() * 100
print(f"Overall Return Rate: {return_rate:.2f}%")
# Out:
# Overall Return Rate: 15.30%

# %% [markdown]
# ### Return Rate by Category

# %%
category_return = df.groupby('Category')['Is Return'].mean().sort_values(ascending=False) * 100
print(category_return)
# Out:
# Category
# Product S    100.000000
# Product T     20.175439
# Product U     20.104439
# Product K     20.000000
# Product J     17.366043
# Product W     17.071349
# Product D     16.880915
# Product H     16.043350
# Product P     15.768061
# Product N     15.710872
# Product R     15.004748
# Product B     14.957265
# Product Q     14.733542
# Product F     14.691943
# Product C     14.413681
# Product A     14.343763
# Product E      9.950249
# Product M      8.463252
# Product L      6.086957
# DPR            1.879699
# Product O      1.813472
# Product G      1.459854
# Product I      0.601202
# Name: Is Return, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.barplot(x=category_return.index, y=category_return.values)
plt.xticks(rotation=60)
plt.ylabel('Return Rate (%)')
plt.title('Return Rate by Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top Returned Products

# %%
top_returns = df[df['Is Return']].groupby(['Item Code', 'Item Name']).size().sort_values(ascending=False).head(10).reset_index(name = 'Return Count')
print(top_returns.to_markdown(index=False))
# Out:
# | Item Code                | Item Name   |   Return Count |
# |:-------------------------|:------------|---------------:|
# | 93-BCE-0C8-1F0-0-CE76A69 | WHX         |            109 |
# | 4A-30E-267-CB3-1-506E7F7 | WHX         |             99 |
# | 85-2EB-163-D62-5-FC50316 | WHX         |             81 |
# | 76-BA0-289-04B-C-9EB5C4F | WHX         |             79 |
# | ED-DCD-031-785-F-999C2B1 | WHX         |             77 |
# | 91-036-77F-B0C-A-F756CA7 | WHX         |             71 |
# | 30-A45-0F8-A47-3-597F220 | WHX         |             69 |
# | 32-AA7-838-2C8-E-1195FE8 | RJF         |             68 |
# | D9-FBB-83F-429-F-51CFE08 | RJF         |             67 |
# | 24-2BA-B62-B5C-D-C72CC19 | YQX         |             63 |

# %% [markdown]
# ### Top Returning Customers

# %%
top_customers = df[df['Is Return']].groupby('Buyer ID').size().sort_values(ascending=False).head(10).reset_index(name = 'Return Count')
print(top_customers.to_markdown(index=False))
# Out:
# |    Buyer ID |   Return Count |
# |------------:|---------------:|
# | 8.32516e+06 |             26 |
# | 2.02861e+06 |             20 |
# | 1.83634e+06 |             16 |
# | 3.14408e+06 |             13 |
# | 5.78625e+06 |             12 |
# | 1.38686e+06 |             12 |
# | 2.59495e+06 |             12 |
# | 2.29919e+06 |             11 |
# | 1.87034e+06 |             11 |
# | 6.08852e+06 |             11 |

# %% [markdown]
# ### Monthly Return Trend

# %%
df['Month'] = df['Date'].dt.to_period('M')
monthly_returns = df.groupby('Month')['Is Return'].mean() * 100

monthly_returns.plot(kind='line', figsize=(10, 5), marker='o', title='Monthly Return Rate (%)')
plt.ylabel('Return Rate (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Total Refunds by Category

# %%
refunds_by_category = df.groupby('Category')['Refunds'].sum().sort_values(ascending=False)

refunds_by_category.plot(kind='bar', figsize=(10,5), title='Total Refunds by Category')
plt.ylabel('Total Refunds')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Return Rate by Discount Band

# %%
def discount_band(x):
    if x <= -50:
        return 'High Discount'
    elif -49 <= x <= -10:
        return 'Moderate Discount'
    else:
        return 'Low/No Discount'

df['Discount Band'] = df['Price Reductions'].apply(discount_band)
discount_group = df.groupby('Discount Band')['Is Return'].mean() * 100

sns.barplot(x=discount_group.index, y=discount_group.values)
plt.ylabel('Return Rate (%)')
plt.title('Return Rate by Discount Band')
plt.show()

# %% [markdown]
# ###  High-Risk Products Export

# %%
product_stats = (
    df.groupby(['Item Code', 'Item Name'])
    .agg(total_orders=('Item Code', 'count'),
         returns=('Is Return', 'sum'),
         return_rate=('Is Return', 'mean'),
         total_refunded=('Refunds', 'sum'))
    .reset_index()
)

high_risk = product_stats[(product_stats['total_orders'] > 5) & (product_stats['returns'] > 1)]
high_risk.loc[:, 'return_rate'] = high_risk['return_rate'] * 100
high_risk.sort_values(by='return_rate', ascending=False).to_csv('high_risk_products.csv', index=False)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_51064\691401660.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_risk.loc[:, 'return_rate'] = high_risk['return_rate'] * 100

# %% [markdown]
# ### Correlation Heatmap (Return Related Features)

# %%
corr_features = df[['Final Quantity', 'Refunds', 'Price Reductions', 'Final Revenue', 'Sales Tax', 'Overall Revenue']]
plt.figure(figsize=(8,6))
sns.heatmap(corr_features.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Heatmap')
plt.show()
